# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pandas_datareader as web
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split


from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

from keras.layers import Dropout

# %%
# Pricing data of NVDA
pricing_data = web.DataReader("NVDA", "yahoo", start = "2022-07-01")

# Importing VIX and oil futures prices as part of the parameter
vix_price = web.DataReader("^VIX", "yahoo" , start = "2022-07-01")
wti_price = web.DataReader("CL=F", "yahoo" , start = "2022-07-01")
qqq_price = web.DataReader("QQQ", "yahoo", start = "2022-07-01")

NVDA_closing_price = pd.DataFrame(pricing_data["Close"])
NVDA_volume = pd.DataFrame(pricing_data["Volume"])
vix_closing_price = pd.DataFrame(vix_price["Close"])
wti_closing_price = pd.DataFrame(wti_price["Close"])
qqq_closing_price = pd.DataFrame(qqq_price["Close"])

# %%
# RSI function
def rsi(df, periods):
    price_diff = df.diff()
    # up / down value
    up = price_diff.clip(lower=0)
    down = -1 * price_diff.clip(upper=0)
    
    # Avg up / Avg down values (SMA)
    ma_up = up.rolling(window = periods).mean()
    ma_down = down.rolling(window = periods).mean()
        
    rsi = ma_up / ma_down
    rsi = 100 - (100/(1 + rsi))
    return rsi

# MACD Function
def macd(df, short_period, long_period, signal_line_period):
    
    short_ewma = df.ewm(span = short_period).mean()
    long_ewma = df.ewm(span = long_period).mean()
    macd = long_ewma - short_ewma
    signal_line = macd.ewm(span = signal_line_period).mean()
    
    return macd, signal_line

# %%
# Putting all the covariates into a dataframe
nvda_rsi = pd.DataFrame(rsi(pricing_data["Close"], periods = 14))
nvda_macd, nvda_signal_line =  macd(pricing_data["Close"], short_period = 12, long_period = 26, signal_line_period = 9)
nvda_macd = pd.DataFrame(nvda_macd)
nvda_signal_line = pd.DataFrame(nvda_signal_line)

# %%
# Splitting x_data 
x_data = pd.concat([NVDA_volume, vix_closing_price, wti_closing_price, qqq_closing_price, nvda_rsi, nvda_macd, nvda_signal_line], axis = 1)
x_data.columns = ["NVDA_volume", "vix_closing_price", "wti_closing_price", "qqq_closing_price", "NVDA_rsi", "NVDA_macd", "NAVD_signal_line"]

# %%
x_data
# Out:
#             NVDA_volume  vix_closing_price  wti_closing_price  \
# Date
# 2017-06-30   73106000.0          11.180000          46.040001
# 2017-07-03   70907200.0          11.220000          47.070000
# 2017-07-05   82018800.0          11.070000          45.130001
# 2017-07-06   74628400.0          12.540000          45.520000
# 2017-07-07   65497200.0          11.190000          44.230000
# ...                 ...                ...                ...
# 2022-10-17   58077400.0          31.370001          85.459999
# 2022-10-18   65936200.0          30.500000          82.820000
# 2022-10-19   52313100.0          30.760000          85.550003
# 2022-10-20   65239800.0          29.980000          85.980003
# 2022-10-21   60893800.0          29.690001          85.050003
#
#             qqq_closing_price   NVDA_rsi  NVDA_macd  NAVD_signal_line
# Date
# 2017-06-30         137.639999        NaN   0.000000          0.000000
# 2017-07-03         136.190002        NaN   0.029335          0.016297
# 2017-07-05         137.529999        NaN   0.008539          0.013118
# 2017-07-06         136.289993        NaN  -0.005009          0.006977
# 2017-07-07         137.759995        NaN  -0.044896         -0.008454
# ...                       ...        ...        ...               ...
# 2022-10-17         269.350006  45.272825   7.218700          7.620366
# 2022-10-18         271.480011  42.757579   6.761158          7.448524
# 2022-10-19         270.489990  48.267383   6.258626          7.210545
# 2022-10-20         269.109985  50.556796   5.679507          6.904337
# 2022-10-21         275.420013  49.524598   4.944077          6.512285
#
# [1340 rows x 7 columns]

# %%
# Splitting y_data 
y_data = pricing_data["Close"]
y_data
# Out:
# Date
# 2017-06-30     36.139999
# 2017-07-03     34.832500
# 2017-07-05     35.762501
# 2017-07-06     35.869999
# 2017-07-07     36.689999
#                  ...
# 2022-10-17    118.879997
# 2022-10-18    119.669998
# 2022-10-19    120.510002
# 2022-10-20    121.940002
# 2022-10-21    124.660004
# Name: Close, Length: 1338, dtype: float64

# %%
# Removing the first few rows which has NA values due to the calculation of RSI and MACD 
total_data = pd.concat([x_data, y_data],axis = 1)
total_data = total_data.dropna()

x_data = total_data[["NVDA_volume", "vix_closing_price", "wti_closing_price", "NVDA_rsi", "NVDA_macd", "NAVD_signal_line"]]
y_data = total_data["Close"]

# %%
# This cell is to split training and testing data, will comment out when training for the final model to predict

# x_train, x_test = pd.Series(train_test_split(x_data.dropna(), test_size = 0.20, random_state = None, shuffle = False))
# y_train, y_test = pd.Series(train_test_split(y_data.dropna(), test_size = 0.20, random_state = None, shuffle = False))

# Final model, testing data will be last 10 days and training data is everything else
x_train = x_data[0:-20]
y_train = y_data
x_test = x_data[-20:]

# %%
y_train
# Out:
# Date
# 2017-07-21     42.025002
# 2017-07-24     41.537498
# 2017-07-25     41.337502
# 2017-07-26     41.814999
# 2017-07-27     40.435001
#                  ...
# 2022-10-17    118.879997
# 2022-10-18    119.669998
# 2022-10-19    120.510002
# 2022-10-20    121.940002
# 2022-10-21    124.660004
# Name: Close, Length: 1324, dtype: float64

# %%
x_test
# Out:
#             NVDA_volume  vix_closing_price  wti_closing_price   NVDA_rsi  \
# Date
# 2022-09-26   54734300.0          32.259998          76.709999  35.920806
# 2022-09-27   55385400.0          32.599998          78.500000  34.973449
# 2022-09-28   54241400.0          30.180000          82.150002  35.671872
# 2022-09-29   53276300.0          31.840000          81.230003  25.895473
# 2022-09-30   56486900.0          31.620001          79.489998  23.463461
# 2022-10-03   54747800.0          30.100000          83.629997  41.047170
# 2022-10-04   58418200.0          29.070000          86.519997  50.474567
# 2022-10-05   50713100.0          28.549999          87.760002  53.542511
# 2022-10-06   64415700.0          30.520000          88.449997  49.096236
# 2022-10-07   67168900.0          31.360001          92.639999  35.902417
# 2022-10-10   69869900.0          32.450001          91.129997  34.416396
# 2022-10-11   66748200.0          33.630001          89.349998  32.664044
# 2022-10-12   49259000.0          33.570000          87.269997  37.419966
# 2022-10-13   85010300.0          31.940001          89.110001  43.998267
# 2022-10-14   71255100.0          32.020000          85.610001  40.141813
# 2022-10-17   58077400.0          31.370001          85.459999  45.272825
# 2022-10-18   65936200.0          30.500000          82.820000  42.757579
# 2022-10-19   52313100.0          30.760000          85.550003  48.267383
# 2022-10-20   65239800.0          29.980000          85.980003  50.556796
# 2022-10-21   60893800.0          29.690001          85.050003  49.524598
#
#             NVDA_macd  NAVD_signal_line
# Date
# 2022-09-26  10.628958         10.305856
# 2022-09-27  10.473883         10.339462
# 2022-09-28   9.975361         10.266642
# 2022-09-29   9.882726         10.189859
# 2022-09-30   9.762141         10.104315
# 2022-10-03   9.258865          9.935225
# 2022-10-04   8.236540          9.595488
# 2022-10-05   7.308205          9.138031
# 2022-10-06   6.560612          8.622548
# 2022-10-07   6.740925          8.246223
# 2022-10-10   7.129250          8.022828
# 2022-10-11   7.419257          7.902114
# 2022-10-12   7.630525          7.847796
# 2022-10-13   7.342138          7.746665
# 2022-10-14   7.617253          7.720782
# 2022-10-17   7.218700          7.620366
# 2022-10-18   6.761158          7.448524
# 2022-10-19   6.258626          7.210545
# 2022-10-20   5.679507          6.904337
# 2022-10-21   4.944077          6.512285

# %%
sc = MinMaxScaler(feature_range = (0,1))
x_train = sc.fit_transform(np.array(x_train))
x_test = sc.fit_transform(np.array(x_test))
y_train = sc.fit_transform(np.array(y_train).reshape(-1,1))
# y_test = sc.fit_transform(np.array(y_test).reshape(-1,1))

x = []
y = []
x_2 = []
# y_2 = []

for i in range(10, x_train.shape[0]):
    x.append(x_train[i-10:i])
    y.append(y_train[i])
    
for i in range(10, x_test.shape[0]):
    x_2.append(x_test[i-10:i])
    y_2.append(y_test[i])
    
x_train = np.array(x)
y_train = np.array(y)
x_test = np.array(x_2)
# y_test = np.array(y_2)

x_train.shape
# Out:
# (1294, 10, 6)

# %%
y_train
# Out:
# array([[0.0332213 ],
#        [0.03747641],
#        [0.03577933],
#        ...,
#        [0.33391833],
#        [0.31073876],
#        [0.30924865]])

# %%
regressor = Sequential()

regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (x_train.shape[1], x_train.shape[2])))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

# regressor.add(LSTM(units = 50, return_sequences = True))
# regressor.add(Dropout(0.2))

regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.2))

regressor.add(Dense(units = 1))

regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')

regressor.fit(x_train, y_train, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 41/41 [==============================] - 7s 9ms/step - loss: 0.0480
# Epoch 2/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0275
# Epoch 3/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0238
# Epoch 4/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0232
# Epoch 5/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0232
# Epoch 6/100
# 41/41 [==============================] - 0s 9ms/step - loss: 0.0211
# Epoch 7/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0209
# Epoch 8/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0188
# Epoch 9/100
# 41/41 [==============================] - 0s 9ms/step - loss: 0.0179
# Epoch 10/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0177
# Epoch 11/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0173
# Epoch 12/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0185
# Epoch 13/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0170
# Epoch 14/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0155
# Epoch 15/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0143
# Epoch 16/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0149
# Epoch 17/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0128
# Epoch 18/100
# 41/41 [==============================] - 0s 9ms/step - loss: 0.0117
# Epoch 19/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0110
# Epoch 20/100
# 41/41 [==============================] - 0s 9ms/step - loss: 0.0108
# Epoch 21/100
# 41/41 [==============================] - 0s 9ms/step - loss: 0.0104
# Epoch 22/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0093
# Epoch 23/100
# 41/41 [==============================] - 0s 9ms/step - loss: 0.0101
# Epoch 24/100
# 41/41 [==============================] - 0s 9ms/step - loss: 0.0104
# Epoch 25/100
# 41/41 [==============================] - 0s 9ms/step - loss: 0.0091
# Epoch 26/100
# 41/41 [==============================] - 0s 9ms/step - loss: 0.0096
# Epoch 27/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0093
# Epoch 28/100
# 41/41 [==============================] - 0s 9ms/step - loss: 0.0086
# Epoch 29/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0085
# Epoch 30/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0093
# Epoch 31/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0082
# Epoch 32/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0092
# Epoch 33/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0078
# Epoch 34/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0074
# Epoch 35/100
# 41/41 [==============================] - 0s 9ms/step - loss: 0.0070
# Epoch 36/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0077
# Epoch 37/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0074
# Epoch 38/100
# 41/41 [==============================] - 0s 9ms/step - loss: 0.0062
# Epoch 39/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0070
# Epoch 40/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0066
# Epoch 41/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0067
# Epoch 42/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0065
# Epoch 43/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0059
# Epoch 44/100
# 41/41 [==============================] - 0s 9ms/step - loss: 0.0107
# Epoch 45/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0062
# Epoch 46/100
# 41/41 [==============================] - 0s 9ms/step - loss: 0.0091
# Epoch 47/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0065
# Epoch 48/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0066
# Epoch 49/100
# 41/41 [==============================] - 0s 9ms/step - loss: 0.0078
# Epoch 50/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0056
# Epoch 51/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0050
# Epoch 52/100
# 41/41 [==============================] - 0s 9ms/step - loss: 0.0071
# Epoch 53/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0063
# Epoch 54/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0072
# Epoch 55/100
# 41/41 [==============================] - 0s 9ms/step - loss: 0.0048
# Epoch 56/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0044
# Epoch 57/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0046
# Epoch 58/100
# 41/41 [==============================] - 0s 9ms/step - loss: 0.0046
# Epoch 59/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0048
# Epoch 60/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0047
# Epoch 61/100
# 41/41 [==============================] - 0s 9ms/step - loss: 0.0052
# Epoch 62/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0057
# Epoch 63/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0079
# Epoch 64/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0043
# Epoch 65/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0048
# Epoch 66/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0040
# Epoch 67/100
# 41/41 [==============================] - 0s 9ms/step - loss: 0.0044
# Epoch 68/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0047
# Epoch 69/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0039
# Epoch 70/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0040
# Epoch 71/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0043
# Epoch 72/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0043
# Epoch 73/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0039
# Epoch 74/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0037
# Epoch 75/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0047
# Epoch 76/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0053
# Epoch 77/100
# 41/41 [==============================] - 0s 9ms/step - loss: 0.0040
# Epoch 78/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0035
# Epoch 79/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0041
# Epoch 80/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0041
# Epoch 81/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0042
# Epoch 82/100
# 41/41 [==============================] - 0s 9ms/step - loss: 0.0088
# Epoch 83/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0057
# Epoch 84/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0038
# Epoch 85/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0037
# Epoch 86/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0039
# Epoch 87/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0036
# Epoch 88/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0035
# Epoch 89/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0032
# Epoch 90/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0036
# Epoch 91/100
# 41/41 [==============================] - 0s 9ms/step - loss: 0.0034
# Epoch 92/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0035
# Epoch 93/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0034
# Epoch 94/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0032
# Epoch 95/100
# 41/41 [==============================] - 0s 9ms/step - loss: 0.0034
# Epoch 96/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0035
# Epoch 97/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0035
# Epoch 98/100
# 41/41 [==============================] - 0s 9ms/step - loss: 0.0034
# Epoch 99/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0041
# Epoch 100/100
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0040

# %%
x_train.shape
# Out:
# (1294, 10, 6)

# %%
y_train.shape
# Out:
# (1294, 1)

# %%
# sc = MinMaxScaler(feature_range = (0,1))
# x_test = sc.fit_transform(np.array(x_test))
# # y_test = sc.fit_transform(np.array(y_test).reshape(-1,1))

# x_2 = []
# # y = []
# for i in range(10, x_test.shape[0]):
#     x.append(x_test[i-10:i])
# #     y.append(y_test[i])

# x_test = np.array(x_2)
# # y_test = np.array(y)

# %%
predicted_stock_price = regressor.predict(x_test)
# Out:
# 1/1 [==============================] - 1s 797ms/step

# %%
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
# y_test = sc.inverse_transform(y_test)

# %%
predicted_stock_price
# Out:
# array([[ 77.33384 ],
#        [ 82.9885  ],
#        [101.85971 ],
#        [ 95.544044],
#        [ 92.758   ],
#        [ 85.83653 ],
#        [ 79.89565 ],
#        [ 76.16965 ],
#        [ 83.60748 ],
#        [134.49588 ]], dtype=float32)

# %%
plt.plot(y_test, color = 'black', label = 'NVDA Stock Price')
plt.plot(predicted_stock_price, color = 'green', label = 'Predicted NVDA Stock Price')
plt.title('NVDA Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('NVDA Stock Price')
plt.legend()
plt.show()
